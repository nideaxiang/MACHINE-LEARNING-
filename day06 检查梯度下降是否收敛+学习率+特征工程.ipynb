# %% [markdown]
# # day06 检查梯度下降是否收敛

# %% [markdown]
# 梯度下降的目的：找到最小成本值
# ![image.png](attachment:image.png)

# %% [markdown]
# 学习曲线：
# ![image.png](attachment:image.png)
# 到400后，不再明显下降，可以认为已经处于收敛

# %% [markdown]
# 若学习率选择正确，那么每次迭代后都应该下降。

# %% [markdown]
# # 选择学习率

# %% [markdown]
# ![image.png](attachment:image.png)
# 成本有时会 上升，有时会下降，梯度下降无法正常工作的明确信号。
# 这可能意味着
# - 代码中存在错误。
# - 学习率太大
#
#
# #### 解决：选择较小的学习率

# %% [markdown]
#  ## 特征工程  feature engineering
#  通过转化、组合形成新的特征

# %% [markdown]
# ## 多项式回归
