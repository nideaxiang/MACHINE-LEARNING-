# %% [markdown]
# 在回归的意义上进行引入，借助阈值0.5进行理解，决策边界：回归线与阈值相交的点的垂线
# ![image.png](attachment:image.png)

# %% [markdown]
# # 逻辑回归
# sigmoid function 也叫逻辑函数
# ![image.png](attachment:image.png)

# %% [markdown]
# 将线性回归中的y换为z，结合两个式子，便可以得到逻辑回归方程：
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 决定边界
# ![image.png](attachment:image.png)
# 可以直接由边界获得结果

# %% [markdown]
# 例如
# ![image.png](attachment:image.png)

# %% [markdown]
# 非线性的决策边界：
# ![image.png](attachment:image.png)

# %% [markdown]
# # 逻辑回归的成本函数问题：借助对数log函数
#
# ![image.png](attachment:image.png)
# 理解：如果真实值为1，预测为0，则无穷大，反之，预测值为1，则成本为0.

# %% [markdown]
# 不使用原来的平方误差成本，是因为逻辑回归模型的特效导致成本函数不呈现凸性

# %% [markdown]
# ## 简化逻辑回归的成本函数
# ![image.png](attachment:image.png)
