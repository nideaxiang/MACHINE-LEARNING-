# %% [markdown]
# # 多元的线性回归和梯度下降

# %% [markdown]
# 矢量化的成本函数的表示：
# ![image.png](attachment:image.png)

# %% [markdown]
# 详细展开：
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 正态方程：梯度下降的替代：
# - 只适用于线性回归
# - 慢
