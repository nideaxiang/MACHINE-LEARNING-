# %% [markdown]
# # 多元线性回归 1

# %% [markdown]
# 引入多个x，输入量变成了一个行向量
# ![image.png](attachment:image.png)

# %% [markdown]
# 更高效的写法：
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 矢量化代码
# 利用 Numpy 线性库

# %%
import Numpy
f=mp.dot(w,x)+b

# %% [markdown]
# 更快的速度：
# ![image.png](attachment:image.png)
