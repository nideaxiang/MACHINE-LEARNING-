# %% [markdown]
# # 第二天笔记 梯度下降 gradient descent

# %% [markdown]
# 梯度下降是一种可以用来尝试最小化任何函数的算法

# %% [markdown]
# ![image.png](attachment:image.png)
# 成本函数或许会具有多个最小点

# %% [markdown]
# Alpha 学习率（下坡的步伐有多大）
# ![image.png](attachment:image.png)
# 导数项-朝着哪一个方向迈出第一步

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 同时更新的梯度下降
# ![image.png](attachment:image.png)
# 错误的不同时更新的梯度下降
# ![image.png](attachment:image.png)

# %% [markdown]
# 学习率 α
# 如果太小 下降很慢 如果太大 下降可能无法下降成功
# ![image.png](attachment:image.png)
