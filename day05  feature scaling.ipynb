# %% [markdown]
# # 使得梯度下降速度更快 特征缩放

# %% [markdown]
# 以房价的预测函数为例，
# 对于p=w1*x1+w2*x2+b来说，w1的相对大小w2很重要
# - 当一个特征的范围很大时，对应的系数值应该小一些

# %% [markdown]
# ![image.png](attachment:image.png)
# 对于w1的改变很微小就能造成很大的改变，同时会造成梯度下降的减缓

# %% [markdown]
# 进行特征缩放
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 如何进行特征缩放
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 均值归一化
# 首先要找到平均值， 也称为训练集上的 x_1 的均值， 我们称之为 mean Mu_1，这是希腊字母 M u
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Z-score 归一化
# 先计算标准差
# ![image.png](attachment:image.png)

# %% [markdown]
# 太大或太小都需要进行特征缩放
# ![image.png](attachment:image.png)
