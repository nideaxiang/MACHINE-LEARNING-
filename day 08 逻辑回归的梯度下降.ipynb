# %% [markdown]
# # 逻辑回归的梯度下降
# 获得最佳的w和b
# - 也需要进行特征缩放，有助于更好地进行梯度下降
# - 可以使用相似地方法进行收敛的确定

# %% [markdown]
# 按照之前的思路
# ![image.png](attachment:image.png)

# %% [markdown]
# 对于导数项的处理：
# ![image.png](attachment:image.png)

# %% [markdown]
# 同步更新的算法：![image.png](attachment:image.png)
